# %%
import qrcode
import matplotlib.pyplot as plt

# %%
data = "https://youtu.be/-sNX_ZMVpQM"

# %%
file_name = "my_qr_code.png"

# %%
image = qrcode.make(data)

# %%
image.save(file_name)

# %%
plt.imshow(image,cmap="gray")

# %%
plt.imshow(image)
